# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules

# %%
dataset = pd.read_csv('/content/loan_train.csv')

# %%
dataset
# Out:
#      Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0      Male      No          0      Graduate            No            584900
# 1      Male     Yes          1      Graduate            No            458300
# 2      Male     Yes          0      Graduate           Yes            300000
# 3      Male     Yes          0  Not Graduate            No            258300
# 4      Male      No          0      Graduate            No            600000
# ..      ...     ...        ...           ...           ...               ...
# 609  Female      No          0      Graduate            No            290000
# 610    Male     Yes         3+      Graduate            No            410600
# 611    Male     Yes          1      Graduate            No            807200
# 612    Male     Yes          2      Graduate            No            758300
# 613  Female      No          0      Graduate           Yes            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 0                   0.0     15000000  360.0             1.0      Urban      Y
# 1              150800.0     12800000  360.0             1.0      Rural      N
# 2                   0.0      6600000  360.0             1.0      Urban      Y
# 3              235800.0     12000000  360.0             1.0      Urban      Y
# 4                   0.0     14100000  360.0             1.0      Urban      Y
# ..                  ...          ...    ...             ...        ...    ...
# 609                 0.0      7100000  360.0             1.0      Rural      Y
# 610                 0.0      4000000  180.0             1.0      Rural      Y
# 611             24000.0     25300000  360.0             1.0      Urban      Y
# 612                 0.0     18700000  360.0             1.0      Urban      Y
# 613                 0.0     13300000  360.0             0.0  Semiurban      N
#
# [614 rows x 12 columns]

# %% [markdown]
# # **Preprocessing**

# %%
dataset.isna().sum()
# Out:
# Gender                13
# Married                3
# Dependents            15
# Education              0
# Self_Employed         32
# Applicant_Income       0
# Coapplicant_Income     0
# Loan_Amount            0
# Term                  14
# Credit_History        50
# Area                   0
# Status                 0
# dtype: int64

# %%
dataset["Credit_History"].unique()
# Out:
# array([ 1.,  0., nan])

# %%
mode_credit_hist = dataset["Credit_History"].mode()[0]
dataset["Credit_History"].fillna(mode_credit_hist, inplace=True)

# %%
mode_term = dataset["Term"].mode()[0]
dataset["Term"].fillna(mode_term, inplace=True)

# %%
mean_loan_amount = dataset["Loan_Amount"].mean()
dataset["Loan_Amount"] = dataset["Loan_Amount"].replace([0.0], [mean_loan_amount])

# %%
mean_coapp_income = dataset["Coapplicant_Income"].mean()
dataset["Coapplicant_Income"] = dataset["Coapplicant_Income"].replace([0.0], [mean_loan_amount])

# %%
# Check if there is any zero value in Applicant_Income
np.where(dataset["Applicant_Income"] == 0.0)
# Out:
# (array([], dtype=int64),)

# %%
mode_self_employed = dataset["Self_Employed"].mode()[0]
dataset["Self_Employed"].fillna(mode_self_employed, inplace=True)

# %%
mode_dependents = dataset["Dependents"].mode()[0]
dataset["Dependents"].fillna(mode_dependents, inplace=True)

# %%
mode_married = dataset["Married"].mode()[0]
dataset["Married"].fillna(mode_married, inplace=True)

# %%
mode_gender = dataset["Gender"].mode()[0]
dataset["Gender"].fillna(mode_gender, inplace=True)

# %%
dataset.isna().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# Applicant_Income      0
# Coapplicant_Income    0
# Loan_Amount           0
# Term                  0
# Credit_History        0
# Area                  0
# Status                0
# dtype: int64

# %%
dataset
# Out:
#      Gender Married Dependents     Education Self_Employed  Applicant_Income  \
# 0      Male      No          0      Graduate            No            584900
# 1      Male     Yes          1      Graduate            No            458300
# 2      Male     Yes          0      Graduate           Yes            300000
# 3      Male     Yes          0  Not Graduate            No            258300
# 4      Male      No          0      Graduate            No            600000
# ..      ...     ...        ...           ...           ...               ...
# 609  Female      No          0      Graduate            No            290000
# 610    Male     Yes         3+      Graduate            No            410600
# 611    Male     Yes          1      Graduate            No            807200
# 612    Male     Yes          2      Graduate            No            758300
# 613  Female      No          0      Graduate           Yes            458300
#
#      Coapplicant_Income  Loan_Amount   Term  Credit_History       Area Status
# 0          1.414104e+07   15000000.0  360.0             1.0      Urban      Y
# 1          1.508000e+05   12800000.0  360.0             1.0      Rural      N
# 2          1.414104e+07    6600000.0  360.0             1.0      Urban      Y
# 3          2.358000e+05   12000000.0  360.0             1.0      Urban      Y
# 4          1.414104e+07   14100000.0  360.0             1.0      Urban      Y
# ..                  ...          ...    ...             ...        ...    ...
# 609        1.414104e+07    7100000.0  360.0             1.0      Rural      Y
# 610        1.414104e+07    4000000.0  180.0             1.0      Rural      Y
# 611        2.400000e+04   25300000.0  360.0             1.0      Urban      Y
# 612        1.414104e+07   18700000.0  360.0             1.0      Urban      Y
# 613        1.414104e+07   13300000.0  360.0             0.0  Semiurban      N
#
# [614 rows x 12 columns]

# %%
# Convert categorical columns from string to integers
categorical_cols = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Term', 'Area']
for col in categorical_cols:
    le = LabelEncoder()
    dataset[col] = le.fit_transform(dataset[col])
dataset
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Applicant_Income  \
# 0         1        0           0          0              0            584900
# 1         1        1           1          0              0            458300
# 2         1        1           0          0              1            300000
# 3         1        1           0          1              0            258300
# 4         1        0           0          0              0            600000
# ..      ...      ...         ...        ...            ...               ...
# 609       0        0           0          0              0            290000
# 610       1        1           3          0              0            410600
# 611       1        1           1          0              0            807200
# 612       1        1           2          0              0            758300
# 613       0        0           0          0              1            458300
#
#      Coapplicant_Income  Loan_Amount  Term  Credit_History  Area Status
# 0          1.414104e+07   15000000.0     8             1.0     2      Y
# 1          1.508000e+05   12800000.0     8             1.0     0      N
# 2          1.414104e+07    6600000.0     8             1.0     2      Y
# 3          2.358000e+05   12000000.0     8             1.0     2      Y
# 4          1.414104e+07   14100000.0     8             1.0     2      Y
# ..                  ...          ...   ...             ...   ...    ...
# 609        1.414104e+07    7100000.0     8             1.0     0      Y
# 610        1.414104e+07    4000000.0     5             1.0     0      Y
# 611        2.400000e+04   25300000.0     8             1.0     2      Y
# 612        1.414104e+07   18700000.0     8             1.0     2      Y
# 613        1.414104e+07   13300000.0     8             0.0     1      N
#
# [614 rows x 12 columns]

# %%
# Apply discretization on continuous value columns
cont_cols = ['Applicant_Income', 'Coapplicant_Income', 'Loan_Amount']
for col in cont_cols:
    dataset[col] = pd.qcut(dataset[col], q=4, labels=False, duplicates='drop')
dataset
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Applicant_Income  \
# 0         1        0           0          0              0                 3
# 1         1        1           1          0              0                 2
# 2         1        1           0          0              1                 1
# 3         1        1           0          1              0                 0
# 4         1        0           0          0              0                 3
# ..      ...      ...         ...        ...            ...               ...
# 609       0        0           0          0              0                 1
# 610       1        1           3          0              0                 2
# 611       1        1           1          0              0                 3
# 612       1        1           2          0              0                 3
# 613       0        0           0          0              1                 2
#
#      Coapplicant_Income  Loan_Amount  Term  Credit_History  Area Status
# 0                     2            2     8             1.0     2      Y
# 1                     0            1     8             1.0     0      N
# 2                     2            0     8             1.0     2      Y
# 3                     1            1     8             1.0     2      Y
# 4                     2            2     8             1.0     2      Y
# ..                  ...          ...   ...             ...   ...    ...
# 609                   2            0     8             1.0     0      Y
# 610                   2            0     5             1.0     0      Y
# 611                   0            3     8             1.0     2      Y
# 612                   2            3     8             1.0     2      Y
# 613                   2            2     8             0.0     1      N
#
# [614 rows x 12 columns]

# %%
transactions = []
for _, row in dataset.iterrows():
    transaction = [f"{column}={value}" for column, value in row.iteritems()]
    transactions.append(transaction)
transactions
# Out:
# <ipython-input-19-e54cb81cf7e1>:3: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   transaction = [f"{column}={value}" for column, value in row.iteritems()]
# [['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=4',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=1',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=6',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=1',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=1',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=5',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=5',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=1',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=2',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=1',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=7',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=9',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=7',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=1',
#   'Self_Employed=1',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=6',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=4',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=9',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=5',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=9',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=4',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=5',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=9',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=7',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=1',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=9',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=7',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=1',
#   'Self_Employed=1',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
# ...
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=1',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=5',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=9',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=3',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=3',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=0',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=6',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=N'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=0',
#   'Coapplicant_Income=1',
#   'Loan_Amount=2',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=N'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=1',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=1',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=1',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=0',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=0',
#   'Loan_Amount=1',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=1',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=3',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=0',
#   'Term=5',
#   'Credit_History=1.0',
#   'Area=0',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=1',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=0',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=1',
#   'Married=1',
#   'Dependents=2',
#   'Education=0',
#   'Self_Employed=0',
#   'Applicant_Income=3',
#   'Coapplicant_Income=2',
#   'Loan_Amount=3',
#   'Term=8',
#   'Credit_History=1.0',
#   'Area=2',
#   'Status=Y'],
#  ['Gender=0',
#   'Married=0',
#   'Dependents=0',
#   'Education=0',
#   'Self_Employed=1',
#   'Applicant_Income=2',
#   'Coapplicant_Income=2',
#   'Loan_Amount=2',
#   'Term=8',
#   'Credit_History=0.0',
#   'Area=1',
#   'Status=N']]

# %%
# Convert the transactions to a binary transaction format
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
transactions_dataset = pd.DataFrame(te_ary, columns=te.columns_)

# Split the transaction data into training and test sets
train_dataset, test_dataset = train_test_split(transactions_dataset, test_size=0.3, random_state=42)

# Generate frequent itemsets
frequent_itemsets = apriori(train_dataset, min_support=0.6, use_colnames=True)
# Generate association rules
association_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
# Print the association rules
association_rules
# Out:
#                               antecedents  \
# 0                           (Education=0)
# 1                    (Credit_History=1.0)
# 2                              (Gender=1)
# 3                    (Credit_History=1.0)
# 4                    (Credit_History=1.0)
# 5                       (Self_Employed=0)
# 6                              (Status=Y)
# 7                    (Credit_History=1.0)
# 8                                (Term=8)
# 9                    (Credit_History=1.0)
# 10                             (Gender=1)
# 11                          (Education=0)
# 12                          (Education=0)
# 13                      (Self_Employed=0)
# 14                               (Term=8)
# 15                          (Education=0)
# 16                             (Gender=1)
# 17                      (Self_Employed=0)
# 18                             (Gender=1)
# 19                               (Term=8)
# 20                             (Status=Y)
# 21                      (Self_Employed=0)
# 22                               (Term=8)
# 23                      (Self_Employed=0)
# 24                             (Status=Y)
# 25                               (Term=8)
# 26           (Term=8, Credit_History=1.0)
# 27  (Self_Employed=0, Credit_History=1.0)
# 28              (Term=8, Self_Employed=0)
# 29                   (Credit_History=1.0)
# 30                               (Term=8)
# 31                      (Self_Employed=0)
# 32                     (Status=Y, Term=8)
# 33         (Status=Y, Credit_History=1.0)
# 34           (Term=8, Credit_History=1.0)
# 35                             (Status=Y)
# 36                               (Term=8)
#
#                               consequents  antecedent support  \
# 0                    (Credit_History=1.0)            0.778555
# 1                           (Education=0)            0.860140
# 2                    (Credit_History=1.0)            0.804196
# 3                              (Gender=1)            0.860140
# 4                       (Self_Employed=0)            0.860140
# 5                    (Credit_History=1.0)            0.862471
# 6                    (Credit_History=1.0)            0.703963
# 7                              (Status=Y)            0.860140
# 8                    (Credit_History=1.0)            0.841492
# 9                                (Term=8)            0.860140
# 10                          (Education=0)            0.804196
# 11                             (Gender=1)            0.778555
# 12                      (Self_Employed=0)            0.778555
# 13                          (Education=0)            0.862471
# 14                          (Education=0)            0.841492
# 15                               (Term=8)            0.778555
# 16                      (Self_Employed=0)            0.804196
# 17                             (Gender=1)            0.862471
# 18                               (Term=8)            0.804196
# 19                             (Gender=1)            0.841492
# 20                      (Self_Employed=0)            0.703963
# 21                             (Status=Y)            0.862471
# 22                      (Self_Employed=0)            0.841492
# 23                               (Term=8)            0.862471
# 24                               (Term=8)            0.703963
# 25                             (Status=Y)            0.841492
# 26                      (Self_Employed=0)            0.734266
# 27                               (Term=8)            0.743590
# 28                   (Credit_History=1.0)            0.731935
# 29              (Term=8, Self_Employed=0)            0.860140
# 30  (Self_Employed=0, Credit_History=1.0)            0.841492
# 31           (Term=8, Credit_History=1.0)            0.862471
# 32                   (Credit_History=1.0)            0.610723
# 33                               (Term=8)            0.692308
# 34                             (Status=Y)            0.734266
# 35           (Term=8, Credit_History=1.0)            0.703963
# 36         (Status=Y, Credit_History=1.0)            0.841492
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.860140  0.675991    0.868263  1.009445  0.006325    1.061666
# 1             0.778555  0.675991    0.785908  1.009445  0.006325    1.034345
# 2             0.860140  0.692308    0.860870  1.000848  0.000587    1.005245
# 3             0.804196  0.692308    0.804878  1.000848  0.000587    1.003497
# 4             0.862471  0.743590    0.864499  1.002351  0.001744    1.014965
# 5             0.860140  0.743590    0.862162  1.002351  0.001744    1.014672
# 6             0.860140  0.692308    0.983444  1.143353  0.086801    8.447552
# 7             0.703963  0.692308    0.804878  1.143353  0.086801    1.517191
# 8             0.860140  0.734266    0.872576  1.014458  0.010465    1.097598
# 9             0.841492  0.734266    0.853659  1.014458  0.010465    1.083139
# 10            0.778555  0.617716    0.768116  0.986592 -0.008395    0.954983
# 11            0.804196  0.617716    0.793413  0.986592 -0.008395    0.947806
# 12            0.862471  0.668998    0.859281  0.996302 -0.002483    0.977335
# 13            0.778555  0.668998    0.775676  0.996302 -0.002483    0.987165
# 14            0.778555  0.673660    0.800554  1.028257  0.018512    1.110302
# 15            0.841492  0.673660    0.865269  1.028257  0.018512    1.176483
# 16            0.862471  0.694639    0.863768  1.001504  0.001043    1.009522
# 17            0.804196  0.694639    0.805405  1.001504  0.001043    1.006216
# 18            0.841492  0.666667    0.828986  0.985138 -0.010058    0.926870
# 19            0.804196  0.666667    0.792244  0.985138 -0.010058    0.942471
# 20            0.862471  0.608392    0.864238  1.002049  0.001244    1.013020
# 21            0.703963  0.608392    0.705405  1.002049  0.001244    1.004897
# 22            0.862471  0.731935    0.869806  1.008505  0.006173    1.056341
# 23            0.841492  0.731935    0.848649  1.008505  0.006173    1.047286
# 24            0.841492  0.610723    0.867550  1.030966  0.018344    1.196737
# 25            0.703963  0.610723    0.725762  1.030966  0.018344    1.079490
# 26            0.862471  0.638695    0.869841  1.008546  0.005412    1.056626
# 27            0.841492  0.638695    0.858934  1.020728  0.012970    1.123647
# 28            0.860140  0.638695    0.872611  1.014500  0.009128    1.097902
# 29            0.731935  0.638695    0.742547  1.014500  0.009128    1.041222
# 30            0.743590  0.638695    0.759003  1.020728  0.012970    1.063955
# 31            0.734266  0.638695    0.740541  1.008546  0.005412    1.024184
# 32            0.860140  0.601399    0.984733  1.144852  0.076092    9.160839
# 33            0.841492  0.601399    0.868687  1.032318  0.018827    1.207101
# 34            0.703963  0.601399    0.819048  1.163482  0.084503    1.635996
# 35            0.734266  0.601399    0.854305  1.163482  0.084503    1.823903
# 36            0.692308  0.601399    0.714681  1.032318  0.018827    1.078417

# %%
# Filter rules based on consequent
loan_status_Yes_rules = association_rules[association_rules['consequents'].apply(lambda x: 'Status=Y' in x)]
loan_status_No_rules = association_rules[association_rules['consequents'].apply(lambda x: 'Status=N' in x)]

# %%
loan_status_Yes_rules
# Out:
#                      antecedents                     consequents  \
# 7           (Credit_History=1.0)                      (Status=Y)
# 21             (Self_Employed=0)                      (Status=Y)
# 25                      (Term=8)                      (Status=Y)
# 34  (Term=8, Credit_History=1.0)                      (Status=Y)
# 36                      (Term=8)  (Status=Y, Credit_History=1.0)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 7             0.860140            0.703963  0.692308    0.804878  1.143353
# 21            0.862471            0.703963  0.608392    0.705405  1.002049
# 25            0.841492            0.703963  0.610723    0.725762  1.030966
# 34            0.734266            0.703963  0.601399    0.819048  1.163482
# 36            0.841492            0.692308  0.601399    0.714681  1.032318
#
#     leverage  conviction
# 7   0.086801    1.517191
# 21  0.001244    1.004897
# 25  0.018344    1.079490
# 34  0.084503    1.635996
# 36  0.018827    1.078417

# %%
loan_status_No_rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
def predict_with_rules(instance, rules):
    predicted_class = []
    max_confidence = 0.7
    for _, rule in rules.iterrows():
        if all(item in instance for item in rule['antecedents']):
            if rule['confidence'] > max_confidence:
                predicted_class = list(rule['consequents'])
                max_confidence = rule['confidence']
    return predicted_class

# Testing on test dataset
test_instances = test_dataset.apply(lambda row: [col for col in test_dataset.columns if row[col]], axis=1)
predictions = test_instances.apply(lambda instance: predict_with_rules(instance, loan_status_Yes_rules))

# %%
# Fetch true status from test data and store in a list
status_Y_test = test_dataset['Status=N']
status_N_test = test_dataset['Status=Y']
y_true = []
for i in status_Y_test:
  if i == True:
    y_true.append('Status=Y')
  else:
    y_true.append('Status=N')

# %%
# Fetch predicted status in a list
y_pred = []
for i in predictions:
  y_pred.append(i[0])

# %%
# Classification Report
classification_repo = classification_report(y_true, y_pred)
print(classification_repo)
# Out:
#               precision    recall  f1-score   support
#
#     Status=N       0.00      0.00      0.00       120
#     Status=Y       0.35      1.00      0.52        65
#
#     accuracy                           0.35       185
#    macro avg       0.18      0.50      0.26       185
# weighted avg       0.12      0.35      0.18       185
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
